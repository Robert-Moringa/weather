# %%
import pandas as pd
import numpy as np
import pandas_profiling as pp

# %%
Data =pd.read_csv("GlobalWeatherRepository1.csv")
#Data =pd.read_csv("GlobalWeatherRepository1.csv",nrows=7)#This okay only when you want to want with 8 entries alone.
Data.head(7)
# Out:
#                country     location_name  latitude  longitude  \
# 0          Afghanistan             Kabul     34.52      69.18
# 1              Albania            Tirana     41.33      19.82
# 2              Algeria           Algiers     36.76       3.05
# 3              Andorra  Andorra La Vella     42.50       1.52
# 4               Angola            Luanda     -8.84      13.23
# 5  Antigua and Barbuda      Saint John's     17.12     -61.85
# 6            Argentina      Buenos Aires    -34.59     -58.67
#
#                          timezone  temperature_celsius condition_text  \
# 0                      Asia/Kabul                 28.8          Sunny
# 1                   Europe/Tirane                 27.0  Partly cloudy
# 2                  Africa/Algiers                 28.0  Partly cloudy
# 3                  Europe/Andorra                 10.2          Sunny
# 4                   Africa/Luanda                 25.0  Partly cloudy
# ...

# %%
print("Shape of the DataFrame:")
print(Data.shape)
# Out:
# Shape of the DataFrame:
# (500, 20)

# %%
print("Data Types of Columns:")
print(Data.dtypes)
# Out:
# Data Types of Columns:
# country                          object
# location_name                    object
# latitude                        float64
# longitude                       float64
# timezone                         object
# temperature_celsius             float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_direction                   object
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# air_quality_Carbon_Monoxide     float64
# air_quality_Ozone               float64
# air_quality_Nitrogen_dioxide    float64
# air_quality_us-epa-index          int64
# air_quality_gb-defra-index        int64
# dtype: object

# %%
Data.nunique()
# Out:
# country                         184
# location_name                   195
# latitude                        191
# longitude                       192
# timezone                        180
# temperature_celsius             127
# condition_text                   17
# wind_mph                         58
# wind_kph                         58
# wind_direction                   16
# precip_mm                        37
# precip_in                        24
# humidity                         81
# cloud                            63
# feels_like_celsius              222
# air_quality_Carbon_Monoxide     172
# air_quality_Ozone               237
# air_quality_Nitrogen_dioxide    168
# air_quality_us-epa-index          6
# air_quality_gb-defra-index       10
# dtype: int64

# %%
Miss_Val = Data.isnull().sum()
Null_val = Data.isna().sum()
print("Missing Values Are:")
print(Miss_Val)

print("NaN Values:")
print(Null_val)
# Out:
# Missing Values Are:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# temperature_celsius             0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_direction                  0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# air_quality_Carbon_Monoxide     0
# air_quality_Ozone               0
# air_quality_Nitrogen_dioxide    0
# air_quality_us-epa-index        0
# air_quality_gb-defra-index      0
# dtype: int64
# NaN Values:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# temperature_celsius             0
# ...

# %%
Data.mode()
# Out:
#        country     location_name  latitude  longitude      timezone  \
# 0     Bulgaria             Accra      41.9     -58.17  Asia/Jakarta
# 1    Indonesia       Addis Ababa       NaN        NaN   Europe/Rome
# 2          NaN           Algiers       NaN        NaN           NaN
# 3          NaN             Amman       NaN        NaN           NaN
# 4          NaN  Andorra La Vella       NaN        NaN           NaN
# ..         ...               ...       ...        ...           ...
# 105        NaN      Vatican City       NaN        NaN           NaN
# 106        NaN            Vienna       NaN        NaN           NaN
# 107        NaN           Vilnius       NaN        NaN           NaN
# 108        NaN           Yerevan       NaN        NaN           NaN
# 109        NaN            Zagreb       NaN        NaN           NaN
#
#      temperature_celsius condition_text  wind_mph  wind_kph wind_direction  \
# ...

# %%
Data.mean()
# Out:
# C:\Users\AA\AppData\Local\Temp\ipykernel_8128\2267807100.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Data.mean()
# latitude                         19.36864
# longitude                        20.94682
# temperature_celsius              23.04140
# wind_mph                          7.22220
# wind_kph                         11.62440
# precip_mm                         0.39920
# precip_in                         0.01552
# humidity                         72.06200
# cloud                            41.00000
# feels_like_celsius               24.87080
# air_quality_Carbon_Monoxide     458.09300
# air_quality_Ozone                46.13480
# air_quality_Nitrogen_dioxide      9.38040
# air_quality_us-epa-index          1.40200
# air_quality_gb-defra-index        1.91400
# dtype: float64

# %%
np.std(Data)
# Out:
# C:\Users\AA\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3579: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# latitude                         24.488153
# longitude                        64.390043
# temperature_celsius               6.919687
# wind_mph                          4.567919
# wind_kph                          7.351218
# precip_mm                         1.912297
# precip_in                         0.075405
# humidity                         21.123592
# cloud                            33.107401
# feels_like_celsius                9.082939
# air_quality_Carbon_Monoxide     761.135540
# air_quality_Ozone                39.694567
# air_quality_Nitrogen_dioxide     19.974342
# air_quality_us-epa-index          0.855801
# ...

# %%
Data2 =Data.drop(['air_quality_us-epa-index', 'air_quality_gb-defra-index'], axis = 1)
Data2
# Out:
#               country     location_name  latitude  longitude  \
# 0         Afghanistan             Kabul     34.52      69.18
# 1             Albania            Tirana     41.33      19.82
# 2             Algeria           Algiers     36.76       3.05
# 3             Andorra  Andorra La Vella     42.50       1.52
# 4              Angola            Luanda     -8.84      13.23
# ..                ...               ...       ...        ...
# 495              Mali            Bamako     12.65      -8.00
# 496             Malta          Valletta     35.90      14.51
# 497  Marshall Islands            Majuro      7.10     171.38
# 498        Mauritania        Nouakchott     18.09     -15.98
# 499         Mauritius        Port Louis    -20.16      57.50
#
#               timezone  temperature_celsius     condition_text  wind_mph  \
# 0           Asia/Kabul                 28.8              Sunny       7.2
# 1        Europe/Tirane                 27.0      Partly cloudy       3.8
# ...

# %%
# Importing
import sklearn
from sklearn.datasets import load_diabetes
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
Data2 = load_diabetes()

# Create the dataframe
column_name = Data2.feature_names
df_Data2 = pd.DataFrame(Data2.data)
df_Data2.columns = column_name
df_Data2.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
# Box Plot
import seaborn as sns
sns.boxplot(Data['precip_mm'])
# Out:
# C:\Users\AA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='precip_mm'>

# %%
# Position of the Outlier
import numpy as np
print(np.where(Data['precip_mm']))
# Out:
# (array([  5,  14,  17,  19,  24,  25,  31,  38,  44,  48,  53,  54,  57,
#         58,  61,  62,  64,  67,  69,  70,  71,  73,  75,  83,  89,  96,
#         97,  98,  99, 100, 101, 103, 104, 105, 111, 115, 117, 121, 127,
#        134, 138, 146, 147, 148, 152, 153, 154, 155, 156, 158, 159, 165,
#        173, 176, 177, 181, 182, 189, 190, 192, 209, 212, 213, 216, 220,
#        224, 232, 233, 239, 242, 243, 248, 250, 257, 258, 263, 264, 265,
#        266, 269, 270, 271, 284, 288, 291, 292, 302, 303, 306, 308, 310,
#        312, 313, 316, 318, 321, 322, 333, 341, 342, 343, 344, 347, 349,
#        350, 351, 354, 355, 357, 358, 360, 363, 370, 371, 376, 378, 384,
#        391, 394, 395, 405, 407, 408, 416, 421, 423, 424, 426, 430, 438,
#        440, 442, 444, 447, 448, 451, 452, 454, 455, 457, 458, 460, 463,
#        464, 465, 479, 486, 487, 488, 493, 494, 497, 498], dtype=int64),)

# %%
# Scatter plot
fig, ax = plt.subplots(figsize = (6,4))
ax.scatter(Data['latitude'],Data['humidity'])

# x-axis label
ax.set_xlabel('(Latitude)')

# y-axis label
ax.set_ylabel('(Humidity )')
plt.show()

# %%
# Z score,, Z- Score is also called a standard score. This value/score helps to understand that how far is the data point from the mean.
from scipy import stats
import numpy as np

z = np.abs(stats.zscore(Data['temperature_celsius']))
print(z)
# Out:
# 0      0.832205
# 1      0.572078
# 2      0.716593
# 3      1.855778
# 4      0.283047
#          ...
# 495    0.427563
# 496    0.138532
# 497    1.150139
# 498    0.470917
# 499    0.295013
# Name: temperature_celsius, Length: 500, dtype: float64
